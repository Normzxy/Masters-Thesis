# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer

# %%
####################
# DATA PREPARATION #
####################

# %%
# DATA DIVISION AND CLARIFICATION #

data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target

X = df.drop('target', axis=1)
Y = df['target']

# %%
df.head(5)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
# DATA SCALING #

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
##############################################
# PERTURB EXISTING POINTS TO CREATE OUTLIERS #
##############################################

# %%
# TO LOAD AND REFRESH CHANGES #

from utils import outliers_generation_functions as ogf
import importlib
importlib.reload(ogf)
# Out:
# <module 'utils.outliers_generation_functions' from 'C:\\Users\\Artur\\Desktop\\PythonProject\\utils\\outliers_generation_functions.py'>

# %%
# CUSTOM FUNCTION TO MODIFY RANDOM EXISTING POINTS TO CREATE OUTLIERS #

perturbed_example, idx_modified = ogf.perturb_within_distribution(
    original_data=df,
    pct_to_perturb=20,
    target_column='target',
    features_to_perturb=15,
    gamma=3.0,
    random_state=101,
    decimal_places=6
)

# %%
# MARKING ROW MODIFICATIONS #

perturbed_example['is_perturbed'] = -1
perturbed_example.loc[idx_modified, 'is_perturbed'] = 1
perturbed_example[perturbed_example['is_perturbed'] == 1]
# Out:
#      mean radius  mean texture  mean perimeter    mean area  mean smoothness  \
# 17     16.130000     20.680000      108.100000  -810.382138         0.117000
# 24     16.650000     21.380000      110.000000  -140.509208         0.112100
# 26      6.706950     21.530000       97.410000   644.800000         0.091537
# 27     18.610000     20.250000      122.100000  1918.093325         0.094400
# 43     38.765658     20.280000       25.276580   545.200000         0.104100
# ..           ...           ...             ...          ...              ...
# 546    25.090879     16.350000       27.515998  1074.781556         0.094340
# 554    14.778418     28.333515      162.202499  -316.420622         0.096108
# 562    15.220000     30.620000      161.541110  -493.431978         0.090658
# 563    29.599911     25.861464      143.000000   958.220939         0.143675
# 565    20.130000     28.250000      131.200000  3318.555796         0.116920
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 17           0.202200        0.385731             0.102800       0.198143
# 24          -0.007330        0.152500             0.197423       0.199500
# 26           0.186800       -0.391272             0.076588       0.225200
# 27           0.145934        0.149000             0.077310       0.288829
# 43           0.223657        0.274699            -0.055416       0.197400
# ..                ...             ...                  ...            ...
# 546          0.049940        0.084120             0.005495       0.254433
# 554          0.058240        0.158757             0.023430       0.258794
# 562          0.101568        0.255000            -0.093999       0.158461
# 563          0.223600        0.317400             0.147400       0.279542
# 565          0.103400        0.111721             0.097910       0.232579
#
#      mean fractal dimension  ...  worst perimeter   worst area  \
# 17                 0.051829  ...       136.800000  1315.000000
# 24                 0.056535  ...       177.000000  2215.000000
# 26                 0.069240  ...       164.430315 -1217.660852
# 27                 0.056990  ...       139.900000   802.593525
# 43                 0.067820  ...        93.704550   912.263294
# ..                      ...  ...              ...          ...
# 546                0.098180  ...        71.120000   384.900000
# 554                0.051507  ...        88.840000   595.700000
# 562                0.086989  ...       175.076495  3416.946142
# 563                0.092072  ...       312.176748  1819.000000
# 565                0.055330  ...       114.567126  1731.000000
#
#      worst smoothness  worst compactness  worst concavity  \
# 17           0.245732           0.423300         0.478400
# 24           0.125785           0.357800         1.150589
# 26           0.112392           0.217429         0.230247
# 27           0.133800          -0.008603         0.344600
# 43           0.153000          -0.178216         0.366400
# ..                ...                ...              ...
# 546          0.128500          -1.184352         0.043840
# 554          0.122700           0.162000         0.384573
# 562          0.046535           0.634054         1.170000
# 563          0.085159           0.418600         1.455224
# 565          0.082235           0.192200         0.321500
#
#      worst concave points  worst symmetry  worst fractal dimension  target  \
# 17               0.375961        0.385580                 0.114200       0
# 24               0.160732        0.361300                 0.095640       0
# 26               0.270100        0.198220                 0.127500       0
# 27               0.149000        0.061726                 0.074210       0
# 43               0.149200        0.373900                 0.102700       0
# ..                    ...             ...                      ...     ...
# 546              0.056307        0.376024                 0.073990       1
# 554              0.064930       -0.165101                 0.072420       1
# 562              0.296600        0.408900                 0.140900       0
# 563              0.254200        0.292900                 0.098730       0
# 565             -0.128177        0.375478                 0.027961       0
#
#      is_perturbed
# 17              1
# 24              1
# 26              1
# 27              1
# 43              1
# ..            ...
# 546             1
# 554             1
# 562             1
# 563             1
# 565             1
#
# [114 rows x 32 columns]

# %%
example_X = perturbed_example.drop(columns=['is_perturbed', 'target'])

# %%
from sklearn.neighbors import LocalOutlierFactor

# %%
# POST-PERTURB DATA SCALING #
example_X_scaled = scaler.fit_transform(example_X)

# NOW 20% IS EXPECTED TO BE OUTLIERS #
lof = LocalOutlierFactor(contamination=0.20, n_neighbors=20)

# %%
# TO CHECK IF NEW OUTLIERS ARE DETECTED #

perturbed_example['outliers_detection'] = lof.fit_predict(example_X_scaled)

perturbed = perturbed_example[perturbed_example['is_perturbed'] == 1].shape[0]
mask = (perturbed_example['is_perturbed'] == 1) & (perturbed_example['outliers_detection'] == -1)
detected = perturbed_example[mask].shape[0]

pct_detected = round((detected/perturbed)*100, 2)
print(f"Percentage of perturbed rows detected by LOF: {pct_detected}%")
# Out:
# Percentage of perturbed rows detected by LOF: 97.37%

# %%
################################################################
# GENERATE MANY FILES WITH ROWS PERTURBATIONS, AND SAVE TO CSV #
################################################################

# %%
percentages = np.arange(1, 51, 1)

for p in percentages:
    df_out = ogf.perturb_within_distribution(
        original_data=df,
        pct_to_perturb=p,
        target_column='target',
        features_to_perturb=15,
        gamma=6.0,
        random_state=101,
        decimal_places=6,
        save=True,
        directory_name='BCW_1to50pct_15of30_g6',
        key_word='perturbed'
    )
