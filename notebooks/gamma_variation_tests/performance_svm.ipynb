# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer

# %%
data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target
# To mark malignant label as 1 #
df['target'] = 1 - df['target']

# %%
# Select constant parameters to select directory
f = 5
p = 25
s = 101

# Mark dictionary key as gamma value for coresponding DataFrame
gammas = np.round(np.arange(0.2, 10.2, 0.2), 1)

# Select metrics to plot
metrics = ['f1_score', 'balanced_accuracy', 'recall']

# True -> save metric results to data/gamma_variation_results.csv
save = True
model_name = 'svm'

# %%
dfs = {0.0 : df}
for g in gammas:
    path = f"../../data/perturbed_datasets/G[Var]_F[{f}]_P[{p}]_S[{s}]/gamma_P[{p}]_F[{f}]_G[{g}].csv"
    dfs[g] = pd.read_csv(path)

# %%
dfs[5.0]
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0      17.990000     10.380000      122.800000     1001.0         0.118400
# 1      20.570000     11.677123      103.216109     1326.0         0.084740
# 2      19.690000     21.250000      130.000000     1203.0         0.109600
# 3      11.420000     20.380000       77.580000      386.1         0.142500
# 4      46.811035     14.340000      135.100000     1297.0         0.023864
# ..           ...           ...             ...        ...              ...
# 564    21.560000     22.390000      142.000000     1479.0         0.111000
# 565    20.130000     28.250000      131.200000     1261.0         0.097800
# 566    16.600000     28.080000      108.300000      858.1         0.084550
# 567    20.600000     29.330000      140.100000     1265.0         0.117800
# 568     7.760000     24.540000       47.920000      181.0         0.052630
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760        0.300100              0.14710       0.241900
# 1             0.07864        0.086900              0.07017       0.189963
# 2             0.15990        0.197400              0.12790       0.206900
# 3             0.28390        0.241400              0.10520       0.259700
# 4             0.13280        1.287348              0.10430       0.180900
# ..                ...             ...                  ...            ...
# 564           0.11590        0.243900              0.13890       0.172600
# 565           0.10340        0.144000              0.09791       0.175200
# 566           0.10230        0.092510              0.05302       0.159000
# 567           0.27700        0.427104              0.15200       0.239700
# 568           0.04362        0.000000              0.00000       0.158700
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                  0.078710  ...          17.33           184.60      2019.0
# 1                  0.056670  ...          23.41           158.80      1956.0
# 2                  0.059990  ...          25.53           152.50      1709.0
# 3                  0.097440  ...          26.50            98.87       567.7
# 4                  0.058830  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                0.056230  ...          26.40           166.10      2027.0
# 565                0.055330  ...          38.25           155.00      1731.0
# 566                0.056480  ...          34.12           126.70      1124.0
# 567                0.080177  ...          39.42           184.60      1821.0
# 568                0.058840  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220           0.665600           0.7119
# 1             0.12380           0.186600           0.2416
# 2             0.14440           0.424500           0.4504
# 3             0.20980           0.866300           0.6869
# 4             0.13740           0.205000           0.4000
# ..                ...                ...              ...
# 564           0.14100           0.211300           0.4107
# 565           0.11660           0.192200           0.3215
# 566           0.11390           0.309400           0.3403
# 567           0.16500           0.466844           0.9387
# 568           0.08996           0.064440           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  target
# 0                  0.2654        0.460100                  0.11890       1
# 1                  0.1860        0.275000                  0.08902       1
# 2                  0.2430        0.361300                  0.08758       1
# 3                  0.2575        0.663800                  0.17300       1
# 4                  0.1625        0.236400                  0.07678       1
# ..                    ...             ...                      ...     ...
# 564                0.2216        0.206000                  0.07115       1
# 565                0.1628        0.257200                  0.06637       1
# 566                0.1418        0.221800                  0.07820       1
# 567                0.2650        0.877647                  0.12400       1
# 568                0.0000        0.287100                  0.07039       0
#
# [569 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, PredefinedSplit
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from datetime import datetime

# %%
from utils import helper_functions as hf
import importlib
importlib.reload(hf)
# Out:
# <module 'utils.helper_functions' from 'C:\\Users\\Artur\\Desktop\\PythonProject\\utils\\helper_functions.py'>

# %%
outer_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=101)

metric_scores = []
for g, df in dfs.items():

    X = df.drop('target', axis=1)
    Y = df['target']

    folds_metric_scores = []
    # Outer U and T split #
    # Loop iteration represents one fold.
    for u_idx, t_idx in outer_cv.split(X, Y):
        X_u, Y_u = X.iloc[u_idx], Y.iloc[u_idx]
        X_t, Y_t = X.iloc[t_idx], Y.iloc[t_idx]

        # Inner X, V and T split #
        (X_x, X_v, Y_x, Y_v) = train_test_split(
            X_u, Y_u, test_size=0.2, stratify=Y_u, random_state=101)

        # Mask to mark training data as -1 and validation as 0.
        # Marking required by PredefinedSplit function below.
        v_fold = np.concatenate([np.full(len(X_x), -1, dtype=int),
                                    np.zeros(len(X_v), dtype=int)])

        # Predefined training/validation split.
        ps = PredefinedSplit(v_fold)

        # GridSearchCV expects (X, Y) as parameters #
        X_for_fit = pd.concat([X_x, X_v], axis=0)
        Y_for_fit = pd.concat([Y_x, Y_v], axis=0)

        # Scaling performed as a part of the process #
        pipe_steps = Pipeline([
        ('scaler', StandardScaler()),
        ('svm', SVC(random_state=101))])

        param_grid = [
            {'svm__kernel': ['linear'],
             'svm__C': np.logspace(-2, 2, 6),
             'svm__class_weight': [None, 'balanced']},

            {'svm__kernel': ['rbf'],
             'svm__C': np.logspace(-2, 2, 6),
             'svm__gamma': ['scale', 1e-4, 1e-3, 1e-2],
             'svm__class_weight': [None, 'balanced']}
        ]

        # Refit on whole outer training set U (X + V), to get the best model
        grid_model = GridSearchCV(pipe_steps, param_grid,
                            cv=ps, scoring='balanced_accuracy', n_jobs=-1, refit=True)
        grid_model.fit(X_for_fit, Y_for_fit)
        best_classifier = grid_model.best_estimator_
        print(best_classifier)

        this_fold_metrics = hf.evaluate_model(best_classifier, X_t, Y_t)
        folds_metric_scores.append(this_fold_metrics)

    fms = pd.DataFrame(folds_metric_scores)

    pct_summary = {
        'model': model_name,
        'pct': p,
        'gamma': g,
        'n_features': f,
        'seed': s,
        **fms.mean(axis=0).to_dict(),
        'timestamp': datetime.now().strftime("%d/%m/%Y %H:%M:%S")
    }

    metric_scores.append(pct_summary)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), gamma=0.01,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm', SVC(C=np.float64(100.0), random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm', SVC(C=np.float64(100.0), random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm', SVC(C=np.float64(100.0), random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.01,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), class_weight='balanced',
#                      gamma=0.001, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.01,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm', SVC(C=np.float64(100.0), random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm', SVC(C=np.float64(100.0), random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), class_weight='balanced',
#                      gamma=0.0001, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), class_weight='balanced',
#                      gamma=0.0001, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), class_weight='balanced',
#                      gamma=0.0001, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), class_weight='balanced',
#                      gamma=0.0001, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), class_weight='balanced',
#                      gamma=0.0001, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), class_weight='balanced',
#                      gamma=0.0001, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), class_weight='balanced',
#                      gamma=0.0001, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), gamma=0.001, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), class_weight='balanced',
#                      gamma=0.0001, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), class_weight='balanced',
#                      gamma=0.0001, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), gamma=0.01,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), class_weight='balanced',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), gamma=0.01,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), gamma=0.01,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.01,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), gamma=0.01,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.01,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), gamma=0.01,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.001,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), gamma=0.001,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.001,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), gamma=0.001,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.001,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), gamma=0.001,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.001,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.01,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.01,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.001,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.01,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.0001,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.01,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.001,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(15.848931924611142), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.0001,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.01,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.001,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.0001,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.01,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.001,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.0001,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.01,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.01,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.01,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.01,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.01,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      gamma=0.01, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.0001,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.0001,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.0001,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), gamma=0.001, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.0001,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), gamma=0.001, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), class_weight='balanced', gamma=0.0001,
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(100.0), gamma=0.001, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), kernel='linear',
#                      random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.06309573444801933), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.3981071705534973), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(2.5118864315095824), class_weight='balanced',
#                      kernel='linear', random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm',
#                  SVC(C=np.float64(0.01), kernel='linear', random_state=101))])

# %%
ms = pd.DataFrame(metric_scores)
ms.head(5)
# Out:
#   model  pct  gamma  n_features  seed  accuracy  precision    recall  \
# 0   svm   25    0.0           5   101  0.977146   0.976517  0.962126
# 1   svm   25    0.2           5   101  0.971852   0.975935  0.947951
# 2   svm   25    0.4           5   101  0.977146   0.981063  0.957364
# 3   svm   25    0.6           5   101  0.977162   0.981063  0.957364
# 4   svm   25    0.8           5   101  0.975408   0.977167  0.957475
#
#    f1_score  specificity  balanced_accuracy            timestamp
# 0  0.969124     0.986033           0.974080  08/11/2025 14:53:43
# 1  0.961546     0.986033           0.966992  08/11/2025 14:53:45
# 2  0.968893     0.988850           0.973107  08/11/2025 14:53:48
# 3  0.968954     0.988850           0.973107  08/11/2025 14:53:51
# 4  0.966877     0.986072           0.971774  08/11/2025 14:53:53

# %%
# Adjust plot parameters
hf.plot_metrics(ms, metrics, 'gamma', 0.2, 'Wartość wzmocnienia', 'Wartość metryki')

# %%
import os

if save:
    filepath = f"../../data/gamma_variation_results.csv"

    if not os.path.exists(filepath):
        ms.to_csv(filepath, index=False)
    else:
        ms.to_csv(filepath, mode='a', header=False, index=False)
