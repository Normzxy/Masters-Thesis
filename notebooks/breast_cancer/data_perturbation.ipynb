# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer

# %%
####################
# DATA PREPARATION #
####################

# %%
# DATA DIVISION AND CLARIFICATION #

data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target

# TO MARK MALIGNANT CASE AS 1 #
df['target'] = 1 - df['target']

X = df.drop('target', axis=1)
Y = df['target']

# %%
df.head(5)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       1
# 1          0.2750                  0.08902       1
# 2          0.3613                  0.08758       1
# 3          0.6638                  0.17300       1
# 4          0.2364                  0.07678       1
#
# [5 rows x 31 columns]

# %%
malignant_pct = round(df['target'].mean() * 100, 2)
malignant_pct
# Out:
# np.float64(37.26)

# %%
##############################################
# PERTURB EXISTING POINTS TO CREATE OUTLIERS #
##############################################

# %%
# TO LOAD AND REFRESH CHANGES #

from utils import outliers_generation_functions as ogf
import importlib
importlib.reload(ogf)
# Out:
# <module 'utils.outliers_generation_functions' from 'C:\\Users\\Artur\\Desktop\\PythonProject\\utils\\outliers_generation_functions.py'>

# %%
# CUSTOM FUNCTION TO MODIFY RANDOM EXISTING POINTS TO CREATE OUTLIERS #

df_modified, idx_modified = ogf.perturb_within_distribution(
    original_data=df,
    pct_to_perturb=25,
    target_column='target',
    feats_to_perturb=10,
    gamma=2.0,
    random_seed=101,
    decimal_places=6
)

# %%
# MARKING ROW MODIFICATIONS #

df_modified['is_perturbed'] = -1
df_modified.loc[idx_modified, 'is_perturbed'] = 1
df_modified[df_modified['is_perturbed'] == 1]
# Out:
#      mean radius  mean texture  mean perimeter    mean area  mean smoothness  \
# 7      13.710000     20.830000       90.200000   577.900000         0.118900
# 9      12.460000     22.126080      107.637739  -383.218262         0.118600
# 10     16.020000     23.240000      102.700000   591.079142         0.082060
# 11     15.780000     17.890000      147.639023  1752.325188         0.097100
# 13     15.850000     27.212093       84.954228   782.700000         0.084010
# ..           ...           ...             ...          ...              ...
# 553     9.333000     21.940000       59.010000  -789.024307         0.092400
# 554    12.880000     29.149943      148.709462   514.300000         0.106421
# 556     7.661491     19.590000      129.106912  1271.575697         0.100300
# 561    17.750611     29.370000       70.670000   386.000000         0.074490
# 562    17.244054     30.620000      103.400000   716.900000         0.104800
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 7            0.164500        0.093660             0.059850       0.167692
# 9            0.239600        0.361849             0.085430       0.166258
# 10           0.066690        0.032990             0.033230       0.202264
# 11           0.129200        0.099540             0.066060       0.184200
# 13           0.100200        0.099380             0.053640       0.119284
# ..                ...             ...                  ...            ...
# 553          0.079791        0.039960             0.012820       0.215097
# 554          0.058240        0.061950             0.023430       0.082691
# 556          0.040295        0.005025            -0.097058       0.179100
# 561          0.035580        0.000000             0.000000       0.106000
# 562          0.208700        0.133336             0.094290       0.203110
#
#      mean fractal dimension  ...  worst perimeter   worst area  \
# 7                  0.074510  ...       110.600000   897.000000
# 9                  0.082430  ...        97.650000  1825.550737
# 10                 0.056970  ...       123.800000  1206.402153
# 11                 0.078312  ...       136.500000  1299.000000
# 13                 0.060555  ...        94.499800   876.500000
# ..                      ...  ...              ...          ...
# 553                0.054848  ...        62.860000   295.800000
# 554                0.057080  ...        88.840000  -109.293019
# 556                0.055360  ...       107.520187   347.300000
# 561                0.050204  ...       191.914439   351.910685
# 562                0.071520  ...       128.700000  2237.141315
#
#      worst smoothness  worst compactness  worst concavity  \
# 7            0.159141           0.187446         0.267800
# 9            0.185300           1.578656         1.105000
# 10           0.173651          -0.244200         0.145900
# 11           0.139600           0.560900         0.991093
# 13           0.113100           0.192400         0.328722
# ..                ...                ...              ...
# 553          0.132436           0.082980         0.079930
# 554          0.122700          -0.055716        -0.364853
# 556          0.126500           0.120000         0.010050
# 561          0.118321           0.542694         0.000000
# 562          0.134549          -0.019482         1.170000
#
#      worst concave points  worst symmetry  worst fractal dimension  target  \
# 7                0.159249        0.167480                 0.088200       1
# 9                0.221000        0.436600                 0.207500       1
# 10               0.099750        0.311421                 0.081486       1
# 11               0.181000        0.379200                 0.108731       1
# 13               0.111900        0.280900                 0.062870       1
# ..                    ...             ...                      ...     ...
# 553              0.025640        0.260399                 0.073930       0
# 554              0.064930        0.237200                 0.072420       0
# 556              0.022320        0.176200                 0.067420       0
# 561              0.000000        0.236157                 0.059050       0
# 562              0.235600        0.408900                 0.143123       1
#
#      is_perturbed
# 7               1
# 9               1
# 10              1
# 11              1
# 13              1
# ..            ...
# 553             1
# 554             1
# 556             1
# 561             1
# 562             1
#
# [142 rows x 32 columns]

# %%
X_modified = df_modified.drop(columns=['is_perturbed', 'target'])

# %%
from sklearn.neighbors import LocalOutlierFactor
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
# POST-PERTURB DATA SCALING #
X_modified_scaled = scaler.fit_transform(X_modified)

# NOW 25% IS EXPECTED TO BE OUTLIERS #
lof = LocalOutlierFactor(contamination=0.25, n_neighbors=20)

# %%
# TO CHECK IF NEW OUTLIERS ARE DETECTED #

df_modified['lof_detection'] = lof.fit_predict(X_modified_scaled)

perturbed = df_modified[df_modified['is_perturbed'] == 1].shape[0]
mask = (df_modified['is_perturbed'] == 1) & (df_modified['lof_detection'] == -1)
detected = df_modified[mask].shape[0]

pct_detected = round((detected/perturbed)*100, 2)
print(f"Percentage of perturbed rows detected by LOF: {pct_detected}%")
df_modified[df_modified['lof_detection'] == -1]
# Out:
# Percentage of perturbed rows detected by LOF: 88.03%
#      mean radius  mean texture  mean perimeter    mean area  mean smoothness  \
# 3      11.420000     20.380000       77.580000   386.100000         0.142500
# 9      12.460000     22.126080      107.637739  -383.218262         0.118600
# 10     16.020000     23.240000      102.700000   591.079142         0.082060
# 13     15.850000     27.212093       84.954228   782.700000         0.084010
# 17     20.860633     18.460615      114.867207  -717.658112         0.117000
# ..           ...           ...             ...          ...              ...
# 553     9.333000     21.940000       59.010000  -789.024307         0.092400
# 554    12.880000     29.149943      148.709462   514.300000         0.106421
# 556     7.661491     19.590000      129.106912  1271.575697         0.100300
# 561    17.750611     29.370000       70.670000   386.000000         0.074490
# 562    17.244054     30.620000      103.400000   716.900000         0.104800
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 3            0.283900        0.241400             0.105200       0.259700
# 9            0.239600        0.361849             0.085430       0.166258
# 10           0.066690        0.032990             0.033230       0.202264
# 13           0.100200        0.099380             0.053640       0.119284
# 17           0.202200        0.172200             0.194738       0.255352
# ..                ...             ...                  ...            ...
# 553          0.079791        0.039960             0.012820       0.215097
# 554          0.058240        0.061950             0.023430       0.082691
# 556          0.040295        0.005025            -0.097058       0.179100
# 561          0.035580        0.000000             0.000000       0.106000
# 562          0.208700        0.133336             0.094290       0.203110
#
#      mean fractal dimension  ...   worst area  worst smoothness  \
# 3                  0.097440  ...   567.700000          0.209800
# 9                  0.082430  ...  1825.550737          0.185300
# 10                 0.056970  ...  1206.402153          0.173651
# 13                 0.060555  ...   876.500000          0.113100
# 17                 0.073560  ...  1315.000000          0.178900
# ..                      ...  ...          ...               ...
# 553                0.054848  ...   295.800000          0.132436
# 554                0.057080  ...  -109.293019          0.122700
# 556                0.055360  ...   347.300000          0.126500
# 561                0.050204  ...   351.910685          0.118321
# 562                0.071520  ...  2237.141315          0.134549
#
#      worst compactness  worst concavity  worst concave points  worst symmetry  \
# 3             0.866300         0.686900               0.25750        0.663800
# 9             1.578656         1.105000               0.22100        0.436600
# 10           -0.244200         0.145900               0.09975        0.311421
# 13            0.192400         0.328722               0.11190        0.280900
# 17            0.614321         0.478400               0.20730        0.370600
# ..                 ...              ...                   ...             ...
# 553           0.082980         0.079930               0.02564        0.260399
# 554          -0.055716        -0.364853               0.06493        0.237200
# 556           0.120000         0.010050               0.02232        0.176200
# 561           0.542694         0.000000               0.00000        0.236157
# 562          -0.019482         1.170000               0.23560        0.408900
#
#      worst fractal dimension  target  is_perturbed  lof_detection
# 3                   0.173000       1            -1             -1
# 9                   0.207500       1             1             -1
# 10                  0.081486       1             1             -1
# 13                  0.062870       1             1             -1
# 17                  0.114200       1             1             -1
# ..                       ...     ...           ...            ...
# 553                 0.073930       0             1             -1
# 554                 0.072420       0             1             -1
# 556                 0.067420       0             1             -1
# 561                 0.059050       0             1             -1
# 562                 0.143123       1             1             -1
#
# [142 rows x 33 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# HOW DO OUTLIERS LOOK IN SPACE? #

cols = ['mean perimeter', 'mean concavity', 'mean radius',
        'mean area', 'mean concave points', 'is_perturbed']
plt.figure(figsize=(10, 10), dpi=500)
sns.pairplot(
    data=df_modified[cols],
    hue='is_perturbed',
    palette='viridis')
plt.show()

# %%
################################################################
# GENERATE MANY FILES WITH ROWS PERTURBATIONS, AND SAVE TO CSV #
################################################################
save_percent_variability = False
save_gamma_variability = False
save_features_variability = False
save_manual_selection = False

# %%
# Percent variability
percentages = np.arange(1, 51, 1)
n = 25
g = 7.0
s = 101

for p in percentages:
    df_out = ogf.perturb_within_distribution(
        original_data=df,
        pct_to_perturb=p,
        target_column='target',
        feats_to_perturb=n,
        gamma=g,
        random_seed=s,
        decimal_places=6,
        save=save_percent_variability,
        directory_name=f"P[Var]_F[{n}]_G[{g}]",
        key_word='percent'
    )

# %%
# Gamma variability
gammas = np.round(np.arange(0.2, 10.2, 0.2), 1)
n = 5
p = 25
s = 101

for g in gammas:
    df_out = ogf.perturb_within_distribution(
        original_data=df,
        pct_to_perturb=p,
        target_column='target',
        feats_to_perturb=n,
        gamma=g,
        random_seed=s,
        decimal_places=6,
        save=save_gamma_variability,
        directory_name=f"G[Var]_F[{n}]_P[{p}]",
        key_word='gamma'
    )

# %%
# Amount of features variability
n_features = np.arange(1, 31, 1)
g = 2.0
p = 25
s = 101

for n in n_features:
    df_out = ogf.perturb_within_distribution(
        original_data=df,
        pct_to_perturb=p,
        target_column='target',
        feats_to_perturb=n,
        gamma=g,
        random_seed=s,
        decimal_places=6,
        save=save_features_variability,
        directory_name=f"F[Var]_G[{g}]_P[{p}]",
        key_word='features'
    )

# %%
# Selected list of features
percentages = np.arange(1, 51, 1)
n = ['mean radius', 'mean perimeter', 'mean area', 'mean compactness', 'mean concavity',
     'worst radius', 'worst perimeter', 'worst area', 'worst compactness', 'mean concave points']
g = 5.0
s = 101

for p in percentages:
    df_out = ogf.perturb_within_distribution(
        original_data=df,
        pct_to_perturb=p,
        target_column='target',
        feats_to_perturb=n,
        gamma=g,
        random_seed=s,
        decimal_places=6,
        save=save_manual_selection,
        directory_name=f"P[Var]_F[HighCorr{len(n)}]_G[{g}]",
        key_word='percent'
    )

# %%
# Selected list of features
percentages = np.arange(1, 51, 1)
n = ['mean radius', 'mean perimeter', 'mean area', 'mean compactness', 'mean concavity',
     'mean fractal dimension', 'symmetry error', 'fractal dimension error', 'texture error', 'smoothness error']
g = 5.0
s = 101

for p in percentages:
    df_out = ogf.perturb_within_distribution(
        original_data=df,
        pct_to_perturb=p,
        target_column='target',
        feats_to_perturb=n,
        gamma=g,
        random_seed=s,
        decimal_places=6,
        save=save_manual_selection,
        directory_name=f"P[Var]_F[LowCorr{len(n)}]_G[{g}]",
        key_word='percent'
    )
