# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer

# %%
data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target
# To mark maligant label as 1 #
df['target'] = 1 - df['target']

# %%
# Select constant parameters to select directory
g = 6.0
p = 25
s = 42

# Mark dictionary key as fetures count value for coresponding DataFrame
n_features = np.arange(1, 31, 1)

# Select metrics to plot
metrics = ['f1_score', 'balanced_accuracy', 'recall']

# True -> save metric results to data/features_variation_results.csv
save = True
model_name = 'forest'

# %%
dfs = {0 : df}
for f in n_features:
    path = f"../../data/perturbed_datasets/F[Var]_G[{g}]_P[{p}]_S[{s}]/features_P[{p}]_F[{f}]_G[{g}].csv"
    dfs[f] = pd.read_csv(path)

# %%
dfs[15]
# Out:
#      mean radius  mean texture  mean perimeter    mean area  mean smoothness  \
# 0          17.99     10.380000          122.80  1001.000000         0.118400
# 1          20.57     17.770000          132.90  1326.000000         0.084740
# 2          19.69     21.250000          130.00  1203.000000         0.109600
# 3          11.42     20.380000           77.58   386.100000         0.142500
# 4          20.29     14.340000          135.10  1297.000000         0.100300
# ..           ...           ...             ...          ...              ...
# 564        21.56     22.390000          142.00  1479.000000         0.111000
# 565        20.13     18.657413          131.20 -1710.366689         0.148806
# 566        16.60     28.080000          108.30   858.100000         0.084550
# 567        20.60     29.330000          140.10  1265.000000         0.117800
# 568         7.76     24.540000           47.92  2381.344786        -0.024322
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0            0.277600        0.300100             0.147100         0.2419
# 1            0.078640        0.086900             0.070170         0.1812
# 2            0.159900        0.197400             0.127900         0.2069
# 3            0.283900        0.241400             0.105200         0.2597
# 4            0.132800        0.198000             0.104300         0.1809
# ..                ...             ...                  ...            ...
# 564          0.115900        0.243900             0.138900         0.1726
# 565          0.186085        0.144000             0.097910         0.1752
# 566          0.102300        0.092510             0.053020         0.1590
# 567          0.277000        0.351400             0.152000         0.2397
# 568          0.043620        0.607558             0.042975         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                  0.078710  ...      17.330000       184.600000      2019.0
# 1                  0.056670  ...      23.410000       158.800000      1956.0
# 2                  0.059990  ...      25.530000       152.500000      1709.0
# 3                  0.097440  ...      26.500000        98.870000       567.7
# 4                  0.058830  ...      16.670000       152.200000      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                0.056230  ...      26.400000       166.100000      2027.0
# 565                0.078741  ...      38.250000       187.118232      1731.0
# 566                0.056480  ...      34.120000       126.700000      1124.0
# 567                0.070160  ...      39.420000       184.600000      1821.0
# 568                0.058840  ...       6.025617       135.469023       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0            0.162200           0.665600         0.711900
# 1            0.123800           0.186600         0.241600
# 2            0.144400           0.424500         0.450400
# 3            0.209800           0.866300         0.686900
# 4            0.137400           0.205000         0.400000
# ..                ...                ...              ...
# 564          0.141000           0.211300         0.410700
# 565          0.224563           1.845067         0.321500
# 566          0.113900           0.309400         0.340300
# 567          0.165000           0.868100         0.938700
# 568          0.089960           0.064440        -3.268496
#
#      worst concave points  worst symmetry  worst fractal dimension  target
# 0                  0.2654        0.460100                 0.118900       1
# 1                  0.1860        0.275000                 0.089020       1
# 2                  0.2430        0.361300                 0.087580       1
# 3                  0.2575        0.663800                 0.173000       1
# 4                  0.1625        0.236400                 0.076780       1
# ..                    ...             ...                      ...     ...
# 564                0.2216        0.206000                 0.071150       1
# 565                0.1628        0.762545                 0.066370       1
# 566                0.1418        0.221800                 0.078200       1
# 567                0.2650        0.408700                 0.124000       1
# 568                0.0000        0.204756                -0.009643       0
#
# [569 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, PredefinedSplit
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from datetime import datetime

# %%
from utils import helper_functions as hf
import importlib
importlib.reload(hf)
# Out:
# <module 'utils.helper_functions' from 'C:\\Users\\Artur\\Desktop\\PythonProject\\utils\\helper_functions.py'>

# %%
outer_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=101)

metric_scores = []
for f, df in dfs.items():

    X = df.drop('target', axis=1)
    Y = df['target']

    folds_metric_scores = []
    # Outer U and T split #
    # Loop iteration represents one fold.
    for u_idx, t_idx in outer_cv.split(X, Y):
        X_u, Y_u = X.iloc[u_idx], Y.iloc[u_idx]
        X_t, Y_t = X.iloc[t_idx], Y.iloc[t_idx]

        # Inner X, V and T split #
        (X_x, X_v, Y_x, Y_v) = train_test_split(
            X_u, Y_u, test_size=0.2, stratify=Y_u, random_state=101)

        # Mask to mark training data as -1 and validation as 0.
        # Marking required by PredefinedSplit function below.
        v_fold = np.concatenate([np.full(len(X_x), -1, dtype=int),
                                    np.zeros(len(X_v), dtype=int)])

        # Predefined training/validation split.
        ps = PredefinedSplit(v_fold)

        # GridSearchCV expects (X, Y) as parameters #
        X_for_fit = pd.concat([X_x, X_v], axis=0)
        Y_for_fit = pd.concat([Y_x, Y_v], axis=0)

        # Scaling performed as a part of the process #
        pipe_steps = Pipeline([
        ('scaler', StandardScaler()),
        ('forest', RandomForestClassifier(random_state=101))])

        param_grid = {
            'forest__n_estimators': [25, 50, 75, 100, 175],
            'forest__criterion': ['gini', 'entropy'],
            'forest__max_features': ['sqrt', 3, 7],
            'forest__bootstrap': [True, False]
        }

        # Refit on whole outer training set U (X + V), to get the best model
        grid_model = GridSearchCV(pipe_steps, param_grid,
                            cv=ps, scoring='balanced_accuracy', n_jobs=-1, refit=True)
        grid_model.fit(X_for_fit, Y_for_fit)
        best_classifier = grid_model.best_estimator_
        print(best_classifier)

        this_fold_metrics = hf.evaluate_model(best_classifier, X_t, Y_t)
        folds_metric_scores.append(this_fold_metrics)

    fms = pd.DataFrame(folds_metric_scores)

    pct_summary = {
        'model': model_name,
        'pct': p,
        'gamma': g,
        'n_features': f,
        'seed': s,
        **fms.mean(axis=0).to_dict(),
        'timestamp': datetime.now().strftime("%d/%m/%Y %H:%M:%S")
    }

    metric_scores.append(pct_summary)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', n_estimators=75,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, n_estimators=175,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', max_features=3,
#                                         n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, n_estimators=175,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, n_estimators=50,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', max_features=3,
#                                         n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=175, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=75, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, n_estimators=175,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=175, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=7, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, n_estimators=50,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         max_features=3, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', n_estimators=175,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, max_features=7,
#                                         n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, n_estimators=75,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy',
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=7, n_estimators=75,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         max_features=3, n_estimators=50,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=75, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         max_features=3, n_estimators=75,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, n_estimators=75,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=75, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, max_features=3,
#                                         n_estimators=75, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, n_estimators=50,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=75, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, max_features=3,
#                                         n_estimators=175, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=7, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest', RandomForestClassifier(random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=175, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, max_features=7,
#                                         n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=7, n_estimators=75,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=7, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=7, n_estimators=75,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         max_features=7, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, max_features=3,
#                                         n_estimators=75, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=7, n_estimators=50,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', n_estimators=75,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=7, n_estimators=175,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         max_features=3, n_estimators=75,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, n_estimators=75,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest', RandomForestClassifier(random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, n_estimators=175,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         max_features=7, n_estimators=75,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=7, n_estimators=75,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=7, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=7, n_estimators=175,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         max_features=7, n_estimators=75,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', max_features=7,
#                                         n_estimators=75, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=7, n_estimators=50,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=175, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, max_features=7,
#                                         n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', max_features=7,
#                                         n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest', RandomForestClassifier(random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, n_estimators=175,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         max_features=3, n_estimators=75,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, max_features=7,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=175, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=175, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         max_features=3, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=7, n_estimators=50,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, n_estimators=175,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, n_estimators=75,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', max_features=3,
#                                         n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=7, n_estimators=175,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=7, n_estimators=50,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         max_features=3, n_estimators=75,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=7, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=175, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', max_features=3,
#                                         n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, max_features=7,
#                                         n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         max_features=3, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', max_features=7,
#                                         n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=175, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', max_features=3,
#                                         n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', n_estimators=75,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=7, n_estimators=75,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', max_features=3,
#                                         n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         max_features=3, n_estimators=75,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         max_features=7, n_estimators=175,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, n_estimators=175,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', max_features=3,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         max_features=7, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, max_features=7,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', max_features=3,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, max_features=3,
#                                         n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         n_estimators=25, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', max_features=3,
#                                         n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, n_estimators=50,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', max_features=3,
#                                         n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', n_estimators=50,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=7, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=7, n_estimators=75,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy',
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         max_features=3, n_estimators=50,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, n_estimators=25,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, max_features=3,
#                                         n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(bootstrap=False, max_features=7,
#                                         n_estimators=50, random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=7, n_estimators=175,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(max_features=3, n_estimators=50,
#                                         random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest', RandomForestClassifier(random_state=101))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('forest',
#                  RandomForestClassifier(criterion='entropy', max_features=7,
#                                         n_estimators=25, random_state=101))])

# %%
ms = pd.DataFrame(metric_scores)
ms.head(5)
# Out:
#     model  pct  gamma  n_features  seed  accuracy  precision    recall  \
# 0  forest   25    6.0           0    42  0.954277   0.952520  0.924252
# 1  forest   25    6.0           1    42  0.963049   0.953548  0.947951
# 2  forest   25    6.0           2    42  0.954277   0.944332  0.933887
# 3  forest   25    6.0           3    42  0.966558   0.962533  0.948062
# 4  forest   25    6.0           4    42  0.957786   0.952544  0.933887
#
#    f1_score  specificity  balanced_accuracy            timestamp
# 0  0.937719     0.971987           0.948120  08/11/2025 16:06:50
# 1  0.950460     0.972027           0.959989  08/11/2025 16:06:58
# 2  0.938681     0.966393           0.950140  08/11/2025 16:07:06
# 3  0.954889     0.977621           0.962842  08/11/2025 16:07:14
# 4  0.942840     0.972027           0.952957  08/11/2025 16:07:23

# %%
# Adjust plot parameters
hf.plot_metrics(ms, metrics, 'n_features', 1, 'Wartość wzmocnienia', 'Wartość metryki')

# %%
import os

if save:
    filepath = f"../../data/features_variation_results.csv"

    if not os.path.exists(filepath):
        ms.to_csv(filepath, index=False)
    else:
        ms.to_csv(filepath, mode='a', header=False, index=False)
